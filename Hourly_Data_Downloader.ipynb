# %% [markdown]
# # Download Hourly Canadian Weather Data
#
# This notebook can be used to browse and download hourly weather data from Environment Canada Weather Stations

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import datetime
import folium
import requests
import os, shutil

# %matplotlib notebook

# token = "pk.eyJ1IjoianVuZXNwYWNlYm9vdHMiLCJhIjoiY2s4a285NTM1MDQwbDNocHozdXlkNzIyaSJ9.-_8gh9gG4VuprIPnmXBr3A" # your mapbox token
# tileurl = 'https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.png?access_token=' + str(token)

# %% [markdown]
# # Search Areas

# %%
## Search Areas (e.g. UBC Micromet flux Search_Locatons)
Search_Locatons =  gpd.read_file('https://raw.githubusercontent.com/ubc-micromet/FieldSiteMaps/main/data/FluxTowers.json')
Search_Locatons = Search_Locatons.set_index('Name')
Search_Locatons.head()
# Out:
#       OBJECTID   Longitude   Latitude  \
# Name
# BB1          4 -122.984947  49.129360
# BB2          5 -122.995163  49.119015
# DSM          6 -122.895210  49.088196
# RBM          7 -123.196411  49.131161
#
#                                                  Access  \
# Name
# BB1   First gate is a yellow gate on 80th Street nex...
# BB2   First gate is a yellow gate on 80th Street nex...
# DSM   Enter the gate through 112th Street, follow th...
# RBM   Get to the West Dyke Trail through Steveston H...
#
#                                                 WebPlot  Start  \
# Name
# BB1   https://ibis.geog.ubc.ca/~micromet/data/burnsb...   2014
# BB2   https://ibis.geog.ubc.ca/~micromet/data/burnsb...   2019
# DSM   https://ibis.geog.ubc.ca/~micromet/data/DeltaS...   2021
# RBM   https://ibis.geog.ubc.ca/~micromet/data/Richmo...   2022
#
#                                             Description  \
# Name
# BB1   A harvested peatland that is undergoing active...
# BB2   A harvested peatland that is not undergoing ac...
# DSM              A degraded salt marsh in boundary bay.
# RBM   A brackish marsh near the mouth of the Fraser ...
#
#                          geometry
# Name
# BB1   POINT (-122.98496 49.12937)
# BB2   POINT (-122.99518 49.11902)
# DSM   POINT (-122.89548 49.08905)
# RBM   POINT (-123.19795 49.13153)

# %% [markdown]
# # Met Stations
#
# Filter Data:
# * Start year (optional)
#     * Calculate record lengths
# * Provinces

# %%
## Met Stations
Start_Year = 2014
Provinces = ['BRITISH COLUMBIA']

End_Year = datetime.datetime.now().year

Stations = pd.read_csv('station_list/Stations.csv',skiprows=0)

Dates = ['FIRST_DATE','LAST_DATE','HLY_FIRST_DATE','HLY_LAST_DATE','DLY_FIRST_DATE','DLY_LAST_DATE',
         'MLY_FIRST_DATE','MLY_LAST_DATE']

for date in Dates:
    Stations[date] = pd.to_datetime(Stations[date])
    
Stations['HLY_REC_LENGTH'] = Stations['HLY_FIRST_DATE']-Stations['HLY_LAST_DATE']

Stations = Stations.loc[((Stations['HLY_FIRST_DATE'].dt.year<=Start_Year)&
                        (Stations['HLY_LAST_DATE'].dt.year>=Start_Year)&
                        (Stations['ENG_PROV_NAME'].isin(Provinces)))].copy()

Stations = Stations.set_index(Stations['STATION_NAME'],drop = True)


Stations = gpd.GeoDataFrame(Stations,
    geometry=gpd.points_from_xy(Stations['x'],
                                Stations['y']
                               ),
                    crs='WGS1984'
                                  )
# Now we can assign a CRS
WGS_1984='epsg:4326'
Stations.crs = WGS_1984
Stations.head()
# Out:
#                           x          y  STN_ID     STATION_NAME  \
# STATION_NAME
# SANDSPIT        -131.813889  53.254167   48648         SANDSPIT
# DELTA BURNS BOG -123.002246  49.125848   49088  DELTA BURNS BOG
# HOPE A          -121.498056  49.368333   49588           HOPE A
# SMITHERS A      -127.182778  54.825278   50130       SMITHERS A
# WILLIAMS LAKE A -122.054444  52.183333   50820  WILLIAMS LAKE A
#
#                 PROV_STATE_TERR_CODE     ENG_PROV_NAME COUNTRY   LATITUDE  \
# STATION_NAME
# SANDSPIT                          BC  BRITISH COLUMBIA     CAN  531515000
# DELTA BURNS BOG                   BC  BRITISH COLUMBIA     CAN  490733053
# HOPE A                            BC  BRITISH COLUMBIA     CAN  492206000
# SMITHERS A                        BC  BRITISH COLUMBIA     CAN  544931000
# WILLIAMS LAKE A                   BC  BRITISH COLUMBIA     CAN  521100000
#
#                   LONGITUDE TIMEZONE  ...       HLY_LAST_DATE DLY_FIRST_DATE  \
# STATION_NAME                          ...
# SANDSPIT        -1314850000      PST  ... 2022-06-07 12:30:00     2010-06-03
# DELTA BURNS BOG -1230008085      PST  ... 2022-06-07 12:30:00     2011-01-25
# HOPE A          -1212953000      PST  ... 2022-06-07 12:30:00     2011-10-20
# SMITHERS A      -1271058000      PST  ... 2022-06-07 12:30:00            NaT
# WILLIAMS LAKE A -1220316000      PST  ... 2022-06-07 12:30:00     2012-12-06
#
#                 DLY_LAST_DATE  MLY_FIRST_DATE MLY_LAST_DATE  \
# STATION_NAME
# SANDSPIT           2022-06-07             NaT           NaT
# DELTA BURNS BOG    2022-06-07             NaT           NaT
# HOPE A             2022-06-07             NaT           NaT
# SMITHERS A                NaT             NaT           NaT
# WILLIAMS LAKE A    2022-06-07             NaT           NaT
#
#                 HAS_MONTHLY_SUMMARY  HAS_NORMALS_DATA  HAS_HOURLY_DATA  \
# STATION_NAME
# SANDSPIT                          Y                 N                Y
# DELTA BURNS BOG                   Y                 N                Y
# HOPE A                            Y                 N                Y
# SMITHERS A                        N                 N                Y
# WILLIAMS LAKE A                   Y                 N                Y
#
#                       HLY_REC_LENGTH                     geometry
# STATION_NAME
# SANDSPIT        -4388 days +22:30:00  POINT (-131.81389 53.25417)
# DELTA BURNS BOG -4219 days +12:30:00  POINT (-123.00225 49.12585)
# HOPE A          -3887 days +18:30:00  POINT (-121.49806 49.36833)
# SMITHERS A      -3711 days +18:30:00  POINT (-127.18278 54.82528)
# WILLIAMS LAKE A -3474 days +20:30:00  POINT (-122.05444 52.18333)
#
# [5 rows x 33 columns]

# %% [markdown]
# # Reproject, Buffer by Radius, and Search
# * Use different projection if outside BC

# %%
## Set to BC Albers
Stations = Stations.to_crs('epsg:3153')
Search_Locatons = Search_Locatons.to_crs('epsg:3153')

## Search Radius
Dist = 10.0e4
Search_Locatons_buffer = Search_Locatons.buffer(Dist)

Select = Stations.assign(**{(key): Stations.within(geom) for key, geom in Search_Locatons_buffer.geometry.items()})

Selection = Select[Select[Search_Locatons.index.values].sum(axis=1)>0].copy()
Not_Selectted = Select[Select[Search_Locatons.index.values].sum(axis=1)==0].copy()

Cols = ['CLIMATE_IDENTIFIER','STN_ID','TC_IDENTIFIER','WMO_IDENTIFIER']

Selection.T#.to_csv('Local_ECC_Stations.csv')
# Out:
# STATION_NAME                                                DELTA BURNS BOG  \
# x                                                               -123.002246
# y                                                                 49.125848
# STN_ID                                                                49088
# STATION_NAME                                                DELTA BURNS BOG
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          490733053
# LONGITUDE                                                       -1230008085
# TIMEZONE                                                                PST
# ELEVATION                                                               3.1
# CLIMATE_IDENTIFIER                                                  1102415
# TC_IDENTIFIER                                                           VBB
# WMO_IDENTIFIER                                                      71042.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                             NaN
# PUBLICATION_CODE                                                        NaN
# DISPLAY_CODE                                                            NaN
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              2010-11-19 01:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          2010-11-19 01:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          2011-01-25 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                                          NaT
# MLY_LAST_DATE                                                           NaT
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                         -4219 days +12:30:00
# geometry                        POINT (1218976.747515727 461249.3506286279)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                          VICTORIA INTL A  \
# x                                                         -123.425833
# y                                                           48.647222
# STN_ID                                                          51337
# STATION_NAME                                          VICTORIA INTL A
# PROV_STATE_TERR_CODE                                               BC
# ENG_PROV_NAME                                        BRITISH COLUMBIA
# COUNTRY                                                           CAN
# LATITUDE                                                    483850000
# LONGITUDE                                                 -1232533000
# TIMEZONE                                                          PST
# ELEVATION                                                        19.5
# CLIMATE_IDENTIFIER                                            1018621
# TC_IDENTIFIER                                                     YYJ
# WMO_IDENTIFIER                                                71799.0
# STATION_TYPE                                         Aviation-Staffed
# NORMAL_CODE                                                       NaN
# PUBLICATION_CODE                                                  NaN
# DISPLAY_CODE                                                      NaN
# ENG_STN_OPERATOR_ACRONYM                                       NAVCAN
# ENG_STN_OPERATOR_NAME                                      NAV Canada
# FIRST_DATE                                        2013-05-16 00:00:00
# LAST_DATE                                         2022-06-07 12:30:00
# HLY_FIRST_DATE                                    2013-07-09 06:00:00
# HLY_LAST_DATE                                     2022-06-07 12:30:00
# DLY_FIRST_DATE                                    2013-05-16 00:00:00
# DLY_LAST_DATE                                     2022-06-07 00:00:00
# MLY_FIRST_DATE                                                    NaT
# MLY_LAST_DATE                                                     NaT
# HAS_MONTHLY_SUMMARY                                                 Y
# HAS_NORMALS_DATA                                                    N
# HAS_HOURLY_DATA                                                     Y
# HLY_REC_LENGTH                                   -3256 days +17:30:00
# geometry                  POINT (1189982.142748618 406916.8766493034)
# BB1                                                              True
# BB2                                                              True
# DSM                                                              True
# RBM                                                              True
#
# STATION_NAME                                                PITT MEADOWS CS  \
# x                                                               -122.690021
# y                                                                 49.208323
# STN_ID                                                                 6830
# STATION_NAME                                                PITT MEADOWS CS
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          491229964
# LONGITUDE                                                       -1224124076
# TIMEZONE                                                                PST
# ELEVATION                                                               5.0
# CLIMATE_IDENTIFIER                                                  1106178
# TC_IDENTIFIER                                                           WMM
# WMO_IDENTIFIER                                                      71775.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1993-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 01:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1993-10-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1993-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +12:30:00
# geometry                        POINT (1241339.588143527 471418.0334451218)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                           VICTORIA GONZALES CS  \
# x                                                               -123.324776
# y                                                                 48.413304
# STN_ID                                                                  114
# STATION_NAME                                           VICTORIA GONZALES CS
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          482447896
# LONGITUDE                                                       -1231929192
# TIMEZONE                                                                PST
# ELEVATION                                                              61.0
# CLIMATE_IDENTIFIER                                                  1018611
# TC_IDENTIFIER                                                           WLM
# WMO_IDENTIFIER                                                      71200.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               G
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            9.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1972-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 00:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1973-01-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1972-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +11:30:00
# geometry                        POINT (1198417.836947194 381251.1652331901)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                         VANCOUVER INTL A  \
# x                                                         -123.183889
# y                                                           49.194722
# STN_ID                                                          51442
# STATION_NAME                                         VANCOUVER INTL A
# PROV_STATE_TERR_CODE                                               BC
# ENG_PROV_NAME                                        BRITISH COLUMBIA
# COUNTRY                                                           CAN
# LATITUDE                                                    491141000
# LONGITUDE                                                 -1231102000
# TIMEZONE                                                          PST
# ELEVATION                                                         4.3
# CLIMATE_IDENTIFIER                                            1108395
# TC_IDENTIFIER                                                     YVR
# WMO_IDENTIFIER                                                71892.0
# STATION_TYPE                                         Aviation-Staffed
# NORMAL_CODE                                                       NaN
# PUBLICATION_CODE                                                  NaN
# DISPLAY_CODE                                                      NaN
# ENG_STN_OPERATOR_ACRONYM                                       NAVCAN
# ENG_STN_OPERATOR_NAME                                      NAV Canada
# FIRST_DATE                                        2013-06-11 06:00:00
# LAST_DATE                                         2022-06-07 12:30:00
# HLY_FIRST_DATE                                    2013-06-11 06:00:00
# HLY_LAST_DATE                                     2022-06-07 12:30:00
# DLY_FIRST_DATE                                    2013-06-13 00:00:00
# DLY_LAST_DATE                                     2022-06-07 00:00:00
# MLY_FIRST_DATE                                                    NaT
# MLY_LAST_DATE                                                     NaT
# HAS_MONTHLY_SUMMARY                                                 Y
# HAS_NORMALS_DATA                                                    N
# HAS_HOURLY_DATA                                                     Y
# HLY_REC_LENGTH                                   -3284 days +17:30:00
# geometry                  POINT (1205411.271972813 468349.9909762481)
# BB1                                                              True
# BB2                                                              True
# DSM                                                              True
# RBM                                                              True
#
# STATION_NAME                                               SQUAMISH AIRPORT  \
# x                                                               -123.161194
# y                                                                 49.783208
# STN_ID                                                                  336
# STATION_NAME                                               SQUAMISH AIRPORT
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          494659550
# LONGITUDE                                                       -1230940300
# TIMEZONE                                                                PST
# ELEVATION                                                              53.7
# CLIMATE_IDENTIFIER                                                  10476F0
# TC_IDENTIFIER                                                           WSK
# WMO_IDENTIFIER                                                      71207.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1982-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1982-05-17 15:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1982-05-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1982-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -14631 days +02:30:00
# geometry                         POINT (1204443.47477172 533773.1233637714)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                       VANCOUVER SEA ISLAND CCG  \
# x                                                               -123.187236
# y                                                                   49.1825
# STN_ID                                                                51357
# STATION_NAME                                       VANCOUVER SEA ISLAND CCG
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          491057000
# LONGITUDE                                                       -1231114050
# TIMEZONE                                                                PST
# ELEVATION                                                               2.1
# CLIMATE_IDENTIFIER                                                  1108380
# TC_IDENTIFIER                                                           VVR
# WMO_IDENTIFIER                                                      71608.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                             NaN
# PUBLICATION_CODE                                                        NaN
# DISPLAY_CODE                                                            NaN
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              2013-03-20 06:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          2013-03-20 06:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          2013-04-25 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                                          NaT
# MLY_LAST_DATE                                                           NaT
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                         -3367 days +17:30:00
# geometry                        POINT (1205221.190652327 466983.4748814637)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                           VANCOUVER HARBOUR CS  \
# x                                                               -123.121869
# y                                                                 49.295353
# STN_ID                                                                  888
# STATION_NAME                                           VANCOUVER HARBOUR CS
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          491743270
# LONGITUDE                                                       -1230718730
# TIMEZONE                                                                PST
# ELEVATION                                                               2.5
# CLIMATE_IDENTIFIER                                                  1108446
# TC_IDENTIFIER                                                           WHC
# WMO_IDENTIFIER                                                      71201.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               D
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            5.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1925-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1976-01-20 07:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1925-11-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1925-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -16941 days +18:30:00
# geometry                         POINT (1209478.12294569 479703.6421253788)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                                NANAIMO A  \
# x                                                             -123.87
# y                                                           49.054444
# STN_ID                                                          52941
# STATION_NAME                                                NANAIMO A
# PROV_STATE_TERR_CODE                                               BC
# ENG_PROV_NAME                                        BRITISH COLUMBIA
# COUNTRY                                                           CAN
# LATITUDE                                                    490316000
# LONGITUDE                                                 -1235212000
# TIMEZONE                                                          PST
# ELEVATION                                                        28.0
# CLIMATE_IDENTIFIER                                            1025365
# TC_IDENTIFIER                                                     YCD
# WMO_IDENTIFIER                                                    NaN
# STATION_TYPE                                            Aviation-Auto
# NORMAL_CODE                                                       NaN
# PUBLICATION_CODE                                                  NaN
# DISPLAY_CODE                                                      NaN
# ENG_STN_OPERATOR_ACRONYM                                       NAVCAN
# ENG_STN_OPERATOR_NAME                                      NAV Canada
# FIRST_DATE                                        2014-10-23 11:00:00
# LAST_DATE                                         2022-06-07 12:30:00
# HLY_FIRST_DATE                                    2014-10-23 11:00:00
# HLY_LAST_DATE                                     2022-06-07 12:30:00
# DLY_FIRST_DATE                                    2018-10-29 00:00:00
# DLY_LAST_DATE                                     2022-06-07 00:00:00
# MLY_FIRST_DATE                                                    NaT
# MLY_LAST_DATE                                                     NaT
# HAS_MONTHLY_SUMMARY                                                 Y
# HAS_NORMALS_DATA                                                    N
# HAS_HOURLY_DATA                                                     Y
# HLY_REC_LENGTH                                   -2785 days +22:30:00
# geometry                  POINT (1155851.942500294 451025.3950323315)
# BB1                                                              True
# BB2                                                              True
# DSM                                                              True
# RBM                                                              True
#
# STATION_NAME                                      VICTORIA HARBOUR A  \
# x                                                          -123.3875
# y                                                          48.422778
# STN_ID                                                         10944
# STATION_NAME                                      VICTORIA HARBOUR A
# PROV_STATE_TERR_CODE                                              BC
# ENG_PROV_NAME                                       BRITISH COLUMBIA
# COUNTRY                                                          CAN
# LATITUDE                                                   482522000
# LONGITUDE                                                -1232315000
# TIMEZONE                                                         PST
# ELEVATION                                                        0.0
# CLIMATE_IDENTIFIER                                           1018615
# TC_IDENTIFIER                                                    YWH
# WMO_IDENTIFIER                                                   NaN
# STATION_TYPE                                        Aviation-Staffed
# NORMAL_CODE                                                      NaN
# PUBLICATION_CODE                                                 NaN
# DISPLAY_CODE                                                     NaN
# ENG_STN_OPERATOR_ACRONYM                                         NaN
# ENG_STN_OPERATOR_NAME                                            NaN
# FIRST_DATE                                       1994-07-01 05:00:00
# LAST_DATE                                        2015-02-12 10:00:00
# HLY_FIRST_DATE                                   1994-07-01 05:00:00
# HLY_LAST_DATE                                    2015-02-12 10:00:00
# DLY_FIRST_DATE                                                   NaT
# DLY_LAST_DATE                                                    NaT
# MLY_FIRST_DATE                                                   NaT
# MLY_LAST_DATE                                                    NaT
# HAS_MONTHLY_SUMMARY                                                N
# HAS_NORMALS_DATA                                                   N
# HAS_HOURLY_DATA                                                    Y
# HLY_REC_LENGTH                                  -7532 days +19:00:00
# geometry                  POINT (1193729.032385471 382127.880988263)
# BB1                                                             True
# BB2                                                             True
# DSM                                                             True
# RBM                                                             True
#
# STATION_NAME                                             ABBOTSFORD A  \
# x                                                             -122.36
# y                                                           49.025278
# STN_ID                                                          50308
# STATION_NAME                                             ABBOTSFORD A
# PROV_STATE_TERR_CODE                                               BC
# ENG_PROV_NAME                                        BRITISH COLUMBIA
# COUNTRY                                                           CAN
# LATITUDE                                                    490131000
# LONGITUDE                                                 -1222136000
# TIMEZONE                                                          PST
# ELEVATION                                                        59.1
# CLIMATE_IDENTIFIER                                            1100031
# TC_IDENTIFIER                                                     YXX
# WMO_IDENTIFIER                                                71108.0
# STATION_TYPE                                         Aviation-Staffed
# NORMAL_CODE                                                       NaN
# PUBLICATION_CODE                                                  NaN
# DISPLAY_CODE                                                      NaN
# ENG_STN_OPERATOR_ACRONYM                                       NAVCAN
# ENG_STN_OPERATOR_NAME                                      NAV Canada
# FIRST_DATE                                        2011-10-07 17:00:00
# LAST_DATE                                         2022-06-07 12:30:00
# HLY_FIRST_DATE                                    2011-10-07 17:00:00
# HLY_LAST_DATE                                     2022-06-07 12:30:00
# DLY_FIRST_DATE                                    2012-06-21 00:00:00
# DLY_LAST_DATE                                     2022-06-07 00:00:00
# MLY_FIRST_DATE                                                    NaT
# MLY_LAST_DATE                                                     NaT
# HAS_MONTHLY_SUMMARY                                                 Y
# HAS_NORMALS_DATA                                                    N
# HAS_HOURLY_DATA                                                     Y
# HLY_REC_LENGTH                                   -3896 days +04:30:00
# geometry                  POINT (1266427.045681126 452292.0338821081)
# BB1                                                              True
# BB2                                                              True
# DSM                                                              True
# RBM                                                              True
#
# STATION_NAME                                         VICTORIA UNIVERSITY CS  \
# x                                                               -123.304611
# y                                                                    48.457
# STN_ID                                                                 6812
# STATION_NAME                                         VICTORIA UNIVERSITY CS
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          482725200
# LONGITUDE                                                       -1231816600
# TIMEZONE                                                                PST
# ELEVATION                                                              60.1
# CLIMATE_IDENTIFIER                                                  1018598
# TC_IDENTIFIER                                                           WYJ
# WMO_IDENTIFIER                                                      71783.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1992-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 00:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1992-12-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1992-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +11:30:00
# geometry                           POINT (1199728.114296 386153.0502547777)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                         HOWE SOUND - PAM ROCKS  \
# x                                                               -123.299453
# y                                                                  49.48778
# STN_ID                                                                 6817
# STATION_NAME                                         HOWE SOUND - PAM ROCKS
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          492916009
# LONGITUDE                                                       -1231758030
# TIMEZONE                                                                PST
# ELEVATION                                                               7.1
# CLIMATE_IDENTIFIER                                                  10459NN
# TC_IDENTIFIER                                                           WAS
# WMO_IDENTIFIER                                                      71211.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1991-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 00:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1991-07-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1991-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +11:30:00
# geometry                        POINT (1195744.074758486 500563.9116759427)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                             WEST VANCOUVER AUT  \
# x                                                               -123.193308
# y                                                                 49.347042
# STN_ID                                                                 6833
# STATION_NAME                                             WEST VANCOUVER AUT
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          492049350
# LONGITUDE                                                       -1231135910
# TIMEZONE                                                                PST
# ELEVATION                                                             170.2
# CLIMATE_IDENTIFIER                                                  1108824
# TC_IDENTIFIER                                                           WWA
# WMO_IDENTIFIER                                                      71784.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1992-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 00:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1992-12-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1992-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +11:30:00
# geometry                         POINT (1204053.73073944 485234.1152370806)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                 WHITE ROCK CAMPBELL SCIENTIFIC  \
# x                                                               -122.783889
# y                                                                 49.018056
# STN_ID                                                                  925
# STATION_NAME                                 WHITE ROCK CAMPBELL SCIENTIFIC
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          490105000
# LONGITUDE                                                       -1224702000
# TIMEZONE                                                                PST
# ELEVATION                                                              13.0
# CLIMATE_IDENTIFIER                                                  1108910
# TC_IDENTIFIER                                                           WWK
# WMO_IDENTIFIER                                                      71785.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                               F
# PUBLICATION_CODE                                                        1.0
# DISPLAY_CODE                                                            7.0
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              1929-01-01 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          1994-02-01 00:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          1929-01-01 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                          1929-01-01 00:00:00
# MLY_LAST_DATE                                           2007-02-01 00:00:00
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                        -10354 days +11:30:00
# geometry                        POINT (1235460.140404583 449988.1886805503)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                                 NORTH COWICHAN  \
# x                                                               -123.718891
# y                                                                 48.824169
# STN_ID                                                                46728
# STATION_NAME                                                 NORTH COWICHAN
# PROV_STATE_TERR_CODE                                                     BC
# ENG_PROV_NAME                                              BRITISH COLUMBIA
# COUNTRY                                                                 CAN
# LATITUDE                                                          484927010
# LONGITUDE                                                       -1234308009
# TIMEZONE                                                                PST
# ELEVATION                                                              44.8
# CLIMATE_IDENTIFIER                                                  1015630
# TC_IDENTIFIER                                                           VOO
# WMO_IDENTIFIER                                                      71927.0
# STATION_TYPE                                                   Climate-Auto
# NORMAL_CODE                                                             NaN
# PUBLICATION_CODE                                                        NaN
# DISPLAY_CODE                                                            NaN
# ENG_STN_OPERATOR_ACRONYM                                         ECCC - MSC
# ENG_STN_OPERATOR_NAME     Environment and Climate Change Canada - Meteor...
# FIRST_DATE                                              2007-11-27 00:00:00
# LAST_DATE                                               2022-06-07 12:30:00
# HLY_FIRST_DATE                                          2007-11-27 08:00:00
# HLY_LAST_DATE                                           2022-06-07 12:30:00
# DLY_FIRST_DATE                                          2007-11-27 00:00:00
# DLY_LAST_DATE                                           2022-06-07 00:00:00
# MLY_FIRST_DATE                                                          NaT
# MLY_LAST_DATE                                                           NaT
# HAS_MONTHLY_SUMMARY                                                       Y
# HAS_NORMALS_DATA                                                          N
# HAS_HOURLY_DATA                                                           Y
# HLY_REC_LENGTH                                         -5307 days +19:30:00
# geometry                        POINT (1167728.672668577 425809.6510269822)
# BB1                                                                    True
# BB2                                                                    True
# DSM                                                                    True
# RBM                                                                    True
#
# STATION_NAME                                                NANAIMO A
# x                                                             -123.87
# y                                                           49.054444
# STN_ID                                                          51318
# STATION_NAME                                                NANAIMO A
# PROV_STATE_TERR_CODE                                               BC
# ENG_PROV_NAME                                        BRITISH COLUMBIA
# COUNTRY                                                           CAN
# LATITUDE                                                    490316000
# LONGITUDE                                                 -1235212000
# TIMEZONE                                                          PST
# ELEVATION                                                        28.0
# CLIMATE_IDENTIFIER                                            1025369
# TC_IDENTIFIER                                                     YCD
# WMO_IDENTIFIER                                                    NaN
# STATION_TYPE                                         Aviation-Staffed
# NORMAL_CODE                                                       NaN
# PUBLICATION_CODE                                                  NaN
# DISPLAY_CODE                                                      NaN
# ENG_STN_OPERATOR_ACRONYM                                       NAVCAN
# ENG_STN_OPERATOR_NAME                                      NAV Canada
# FIRST_DATE                                        2013-05-16 11:00:00
# LAST_DATE                                         2022-06-07 12:30:00
# HLY_FIRST_DATE                                    2013-05-16 11:00:00
# HLY_LAST_DATE                                     2022-06-07 12:30:00
# DLY_FIRST_DATE                                    2016-06-02 00:00:00
# DLY_LAST_DATE                                     2022-04-30 00:00:00
# MLY_FIRST_DATE                                                    NaT
# MLY_LAST_DATE                                                     NaT
# HAS_MONTHLY_SUMMARY                                                 Y
# HAS_NORMALS_DATA                                                    N
# HAS_HOURLY_DATA                                                     Y
# HLY_REC_LENGTH                                   -3310 days +22:30:00
# geometry                  POINT (1155851.942500294 451025.3950323315)
# BB1                                                              True
# BB2                                                              True
# DSM                                                              True
# RBM                                                              True

# %% [markdown]
# # Display Results in Interactive Webmap

# %%
Map = folium.Map(
    location=[49.12917,-122.98486], zoom_start=10)#, tiles=tileurl, attr='Mapbox')

def pop_Up_Table(row):
    pop_up='''<table>
    <tr><td><b>Station Name: </b></td>><td>'''+row['STATION_NAME']+'''</td><tr>
    <tr><td><b>Start Date: </b></td>><td>'''+row['HLY_FIRST_DATE'].strftime("%d/%m/%Y")+'''</td><tr>
    <tr><td><b>End Date: </b></td>><td>'''+row['HLY_LAST_DATE'].strftime("%d/%m/%Y")+'''</td><tr>
    </table>
    '''
    return (pop_up)

for i,row in Search_Locatons.iterrows():
    print(row['Latitude'],row['Longitude'])
    point=folium.CircleMarker(
            location=[row['Latitude'],row['Longitude']],
            radius=10,
            popup=i,
            fill_opacity = 1,
            fill=True,
            color='black',
            line_weight=.35,
            fill_color='blue'
    ).add_to(Map)

    
    
    
for i,row in Not_Selectted.iterrows():
    point=folium.CircleMarker(
            location=[row['y'],row['x']],
            radius=5,
            popup = folium.Popup(pop_Up_Table(row), min_width=300, max_width=300),
            fill_opacity = 1,
            fill=True,
            color='black',
            line_weight=.35,
            fill_color='grey'
    ).add_to(Map)

    
for i,row in Selection.iterrows():
    point=folium.CircleMarker(
            location=[row['y'],row['x']],
            radius=5,
            popup = folium.Popup(pop_Up_Table(row), min_width=300, max_width=300),
            fill_opacity = 1,
            fill=True,
            color='black',
            line_weight=.35,
            fill_color='red'
    ).add_to(Map)
Map
# Out:
# 49.12936019897461 -122.98494720458984
# 49.119014739990234 -122.99516296386719
# 49.08819580078125 -122.89521026611328
# 49.131160736083984 -123.1964111328125
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bf82b9e812a2412ba39d20646e8c6755%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bf82b9e812a2412ba39d20646e8c6755%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bf82b9e812a2412ba39d20646e8c6755%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bf82b9e812a2412ba39d20646e8c6755%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.12917%2C%20-122.98486%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Download Data

# %%
def Clear(folder):
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))
Path = 'Data/'
print('Cleaning ' +Path+ ' Folder')
Clear(Path)

for i,row in Selection.iterrows():
    Root = 'https://api.weather.gc.ca/collections/climate-hourly/items?'

    Start_Year = 2014
    End_Year = 2022

#     Range = 'datetime='+str(Start_Year)+'-01-01%2000:00:00/'+str(End_Year)+'-12-31%2000:00:00'
    Range = 'datetime='+str(2021)+'-06-29%2000:00:00/'+str(End_Year)+'-06-30%2000:00:00'

    Station = '&CLIMATE_IDENTIFIER='+str(row['CLIMATE_IDENTIFIER'])

    End = '&sortby=LOCAL_DATE&f=csv&limit=100000&startindex=0'

    Download = (Root+Range+Station+End)
    response = requests.get(Download)
    open(Path+str(i)+".csv", "wb").write(response.content)
    print('Downloaded: ',i)
Selection.to_csv(Path+'Inventory.csv')
print('Download Complete')
# Out:
# Cleaning Data/ Folder
# Downloaded:  DELTA BURNS BOG
# Downloaded:  VICTORIA INTL A
# Downloaded:  PITT MEADOWS CS
# Downloaded:  VICTORIA GONZALES CS
# Downloaded:  VANCOUVER INTL A
# Downloaded:  SQUAMISH AIRPORT
# Downloaded:  VANCOUVER SEA ISLAND CCG
# Downloaded:  VANCOUVER HARBOUR CS
# Downloaded:  NANAIMO A
# Downloaded:  VICTORIA HARBOUR A
# Downloaded:  ABBOTSFORD A
# Downloaded:  VICTORIA UNIVERSITY CS
# Downloaded:  HOWE SOUND - PAM ROCKS
# Downloaded:  WEST VANCOUVER AUT
# Downloaded:  WHITE ROCK CAMPBELL SCIENTIFIC
# Downloaded:  NORTH COWICHAN
# Downloaded:  NANAIMO A
# Download Complete
